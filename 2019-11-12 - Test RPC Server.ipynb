# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def to_string(arr):
    import json
    s=json.dumps(arr.tolist())
    return s

def from_string(s):
    import json
    from numpy import array
    arr=array(json.loads(s))
    return arr

def take_picture(): # takes a random one from the list
    # replace this function with one that actually takes a picture
    from glob import glob
    from random import choice
    from pylab import imread
    
    fnames=glob('/Users/bblais/Desktop/ai373/images/board images/*.jpg')
    
    arr=imread(choice(fnames))
    return to_string(arr)

def take_picture():  # takes the newest one in the list
    # replace this function with one that actually takes a picture
    from glob import glob
    import os
    fnames=glob('/Users/bblais/Desktop/ai373/images/board images/*.jpg')

    newest = max(fnames, key=os.path.getctime)
    arr=imread(newest)
    return to_string(arr)

# %%
a=rand(3,4)
a
# Out:
# array([[0.78851545, 0.65691818, 0.65665977, 0.86828421],
#        [0.0033113 , 0.22751984, 0.64856487, 0.72707303],
#        [0.60211971, 0.21524066, 0.93864958, 0.9202812 ]])

# %%
from_string(to_string(a))
# Out:
# array([[0.78851545, 0.65691818, 0.65665977, 0.86828421],
#        [0.0033113 , 0.22751984, 0.64856487, 0.72707303],
#        [0.60211971, 0.21524066, 0.93864958, 0.9202812 ]])

# %%
arr=from_string(take_picture())
imshow(arr)

# %%
from xmlrpc.server import SimpleXMLRPCServer
from xmlrpc.server import SimpleXMLRPCRequestHandler

# Restrict to a particular path.
class RequestHandler(SimpleXMLRPCRequestHandler):
    rpc_paths = ('/RPC2',)

# Create server
with SimpleXMLRPCServer(('localhost', 8001),
                        requestHandler=RequestHandler) as server:
    server.register_introspection_functions()

    server.register_function(take_picture)

    # Run the server's main loop
    server.serve_forever()
# Out:
# 127.0.0.1 - - [12/Nov/2019 10:57:27] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:57:27] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:57:27] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:57:27] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:57:27] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:57:57] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:57:57] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:57:57] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:57:57] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:57:57] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:58:05] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:58:05] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:58:05] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:58:05] "POST /RPC2 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Nov/2019 10:58:05] "POST /RPC2 HTTP/1.1" 200 -
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-0b5e22a91ee9> in <module>
#      29
#      30     # Run the server's main loop
# ---> 31     server.serve_forever()
#
# ~/anaconda3/lib/python3.7/socketserver.py in serve_forever(self, poll_interval)
#     230
#     231                 while not self.__shutdown_request:
# --> 232                     ready = selector.select(poll_interval)
#     233                     # bpo-35017: shutdown() called during select(), exit immediately.
#     234                     if self.__shutdown_request:
#
# ~/anaconda3/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
